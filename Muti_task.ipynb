# %%
from google.colab import drive
drive.mount('/content/drive')

import os

folder_path = "/content/drive/MyDrive/IFT6289_final_project"

#将作业文件夹链接到名为 /content/project 的新文件夹。该命令使用 ln -Ts 命令将作业文件夹的符号链接链接到 Colab 上的新文件夹。这将使您能够在
# !ln -Ts "$folder_path" /content/project 2> /dev/null

import sys

# Add the assignment folder to Python path
if '/content/project' not in sys.path:
  sys.path.insert(0, '/content/project')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch torchvision -U
# !pip install tqdm==4.58.0
# !pip install requests==2.25.1
# !pip install importlib-metadata==3.7.0
# !pip install filelock==3.0.12
# !pip install sklearn==0.0
# !pip install tokenizers
# !pip install explainaboard_client==0.0.7
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.1+cu118)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tqdm==4.58.0
#   Downloading tqdm-4.58.0-py2.py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
# Successfully installed tqdm-4.58.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting requests==2.25.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from requests==2.25.1) (4.0.0)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.25.1) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.25.1) (2022.12.7)
# Installing collected packages: idna, requests
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yfinance 0.2.18 requires requests>=2.26, but you have requests 2.25.1 which is incompatible.
# tweepy 4.13.0 requires requests<3,>=2.27.0, but you have requests 2.25.1 which is incompatible.
# google-colab 1.0.0 requires requests>=2.27.0, but you have requests 2.25.1 which is incompatible.
# Successfully installed idna-2.10 requests-2.25.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting importlib-metadata==3.7.0
#   Downloading importlib_metadata-3.7.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata==3.7.0) (3.15.0)
# Installing collected packages: importlib-metadata
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.6.0
#     Uninstalling importlib-metadata-6.6.0:
#       Successfully uninstalled importlib-metadata-6.6.0
# Successfully installed importlib-metadata-3.7.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting filelock==3.0.12
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Installing collected packages: filelock
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.12.0
#     Uninstalling filelock-3.12.0:
#       Successfully uninstalled filelock-3.12.0
# Successfully installed filelock-3.0.12
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sklearn==0.0
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sklearn==0.0) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sklearn==0.0) (1.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sklearn==0.0) (1.22.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sklearn==0.0) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sklearn==0.0) (1.2.0)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=d83f28428d94e93ba6cae1eb8f83aa578a930b5e787f51a9a2fc5e32ee282156
#   Stored in directory: /root/.cache/pip/wheels/9b/13/01/6f3a7fd641f90e1f6c8c7cded057f3394f451f340371c68f3d
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tokenizers
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 94.8 MB/s eta 0:00:00
# Installing collected packages: tokenizers
# Successfully installed tokenizers-0.13.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting explainaboard_client==0.0.7
#   Downloading explainaboard_client-0.0.7-py2.py3-none-any.whl (16 kB)
# Collecting explainaboard-api-client>=0.2.0
#   Downloading explainaboard_api_client-0.4.3-py2.py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.7/184.7 kB 22.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from explainaboard_client==0.0.7) (4.58.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from explainaboard-api-client>=0.2.0->explainaboard_client==0.0.7) (2.8.2)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.10/dist-packages (from explainaboard-api-client>=0.2.0->explainaboard_client==0.0.7) (1.26.15)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->explainaboard-api-client>=0.2.0->explainaboard_client==0.0.7) (1.16.0)
# Installing collected packages: explainaboard-api-client, explainaboard_client
# Successfully installed explainaboard-api-client-0.4.3 explainaboard_client-0.0.7

# %%
# !python3 /content/project/multitask_classifier.py --option finetune --epochs 10 --lr 1e-5 --batch_size 64 --hidden_dropout_prob 0.3 --use_gpu
# Out:
# Loaded 8544 train examples from /content/project/data/ids-sst-train.csv
# Loaded 141498 train examples from /content/project/data/quora-train.csv
# Loaded 6040 train examples from /content/project/data/sts-train.csv
# Loaded 1101 train examples from /content/project/data/ids-sst-dev.csv
# Loaded 20212 train examples from /content/project/data/quora-dev.csv
# Loaded 863 train examples from /content/project/data/sts-dev.csv
# Downloading: 100% 232k/232k [00:00<00:00, 14.4MB/s]
# Downloading: 100% 570/570 [00:00<00:00, 674kB/s]
# Downloading: 100% 440M/440M [00:03<00:00, 114MB/s]
# 2211it [10:12,  3.61it/s]
# Paraphrase detection accuracy: 0.757
# Sentiment classification accuracy: 0.314
# Semantic Textual Similarity correlation: 0.099
# Epoch 1/10, Loss: 0.6738459503472741, accs: Sentiment: 0.314, Paraphrase: 0.757, Similarity: 0.099.
# save the model to finetune-10-1e-05-multitask.pt
# New best development scores: Sentiment: 0.314, Paraphrase: 0.757, Similarity: 0.099. Model saved.
# 2211it [10:11,  3.61it/s]
# Paraphrase detection accuracy: 0.768
# Sentiment classification accuracy: 0.492
# Semantic Textual Similarity correlation: 0.220
# Epoch 2/10, Loss: 0.5789723483915514, accs: Sentiment: 0.492, Paraphrase: 0.768, Similarity: 0.220.
# save the model to finetune-10-1e-05-multitask.pt
# New best development scores: Sentiment: 0.492, Paraphrase: 0.768, Similarity: 0.220. Model saved.
# 2211it [10:09,  3.63it/s]
# Paraphrase detection accuracy: 0.772
# Sentiment classification accuracy: 0.488
# Semantic Textual Similarity correlation: 0.336
# Epoch 3/10, Loss: 0.5115019330095242, accs: Sentiment: 0.488, Paraphrase: 0.772, Similarity: 0.336.
# save the model to finetune-10-1e-05-multitask.pt
# New best development scores: Sentiment: 0.492, Paraphrase: 0.772, Similarity: 0.336. Model saved.
# 2211it [10:11,  3.62it/s]
# Paraphrase detection accuracy: 0.779
# Sentiment classification accuracy: 0.510
# Semantic Textual Similarity correlation: 0.368
# Epoch 4/10, Loss: 0.4429122088034732, accs: Sentiment: 0.510, Paraphrase: 0.779, Similarity: 0.368.
# save the model to finetune-10-1e-05-multitask.pt
# New best development scores: Sentiment: 0.510, Paraphrase: 0.779, Similarity: 0.368. Model saved.
# 2211it [10:10,  3.62it/s]
# Paraphrase detection accuracy: 0.751
# Sentiment classification accuracy: 0.529
# Semantic Textual Similarity correlation: 0.392
# Epoch 5/10, Loss: 0.373366570887874, accs: Sentiment: 0.529, Paraphrase: 0.751, Similarity: 0.392.
# save the model to finetune-10-1e-05-multitask.pt
# New best development scores: Sentiment: 0.529, Paraphrase: 0.779, Similarity: 0.392. Model saved.
# 2211it [10:10,  3.62it/s]
# Paraphrase detection accuracy: 0.778
# Sentiment classification accuracy: 0.497
# Semantic Textual Similarity correlation: 0.374
# Epoch 6/10, Loss: 0.30743233183224455, accs: Sentiment: 0.497, Paraphrase: 0.778, Similarity: 0.374.
# 2211it [10:11,  3.62it/s]
# Paraphrase detection accuracy: 0.769
# Sentiment classification accuracy: 0.480
# Semantic Textual Similarity correlation: 0.399
# Epoch 7/10, Loss: 0.2549592472077063, accs: Sentiment: 0.480, Paraphrase: 0.769, Similarity: 0.399.
# save the model to finetune-10-1e-05-multitask.pt
# New best development scores: Sentiment: 0.529, Paraphrase: 0.779, Similarity: 0.399. Model saved.
# 2211it [10:10,  3.62it/s]
# Paraphrase detection accuracy: 0.753
# Sentiment classification accuracy: 0.492
# Semantic Textual Similarity correlation: 0.390
# Epoch 8/10, Loss: 0.20924120003964933, accs: Sentiment: 0.492, Paraphrase: 0.753, Similarity: 0.390.
# 2211it [10:10,  3.62it/s]
# Paraphrase detection accuracy: 0.769
# Sentiment classification accuracy: 0.499
# Semantic Textual Similarity correlation: 0.406
# Epoch 9/10, Loss: 0.17509326791666255, accs: Sentiment: 0.499, Paraphrase: 0.769, Similarity: 0.406.
# save the model to finetune-10-1e-05-multitask.pt
# New best development scores: Sentiment: 0.529, Paraphrase: 0.779, Similarity: 0.406. Model saved.
# 2211it [10:12,  3.61it/s]
# Paraphrase detection accuracy: 0.777
# Sentiment classification accuracy: 0.476
# Semantic Textual Similarity correlation: 0.404
# Epoch 10/10, Loss: 0.14991113409898713, accs: Sentiment: 0.476, Paraphrase: 0.777, Similarity: 0.404.
# Loaded model to test from finetune-10-1e-05-multitask.pt
# Loaded 2210 test examples from /content/project/data/ids-sst-test-student.csv
# Loaded 40431 test examples from /content/project/data/quora-test-student.csv
# Loaded 1725 test examples from /content/project/data/sts-test-student.csv
# Loaded 1101 dev examples from /content/project/data/ids-sst-dev.csv
# Loaded 20212 dev examples from /content/project/data/quora-dev.csv
# Loaded 863 dev examples from /content/project/data/sts-dev.csv
# Paraphrase detection accuracy: 0.769
# Sentiment classification accuracy: 0.499
# Semantic Textual Similarity correlation: 0.409
# dev sentiment acc :: 0.499
# dev paraphrase acc :: 0.769
# dev sts corr :: 0.409
